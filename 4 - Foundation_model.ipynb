# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratheeba21/Advanced-Generative-AI/blob/main/4%20-%20Foundation_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets -q

# %%
from huggingface_hub import login
login()

# %%
from transformers import pipeline

classifier = pipeline('sentiment-analysis')
print(classifier('I absolutely love this generative AI course!'))

generator = pipeline('text-generation', model='gpt2')
output = generator('Generative AI is', max_new_tokens=50, num_return_sequences=3)
print(output[0]['generated_text'])
print(output[1]['generated_text'])
print(output[2]['generated_text'])
