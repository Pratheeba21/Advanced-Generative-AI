# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratheeba21/Advanced-Generative-AI/blob/main/7_IBM_Granite_via_Hugging_Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_id = 'ibm-granite/granite-3.1-2b-instruct'

tokenizer = AutoTokenizer.from_pretrained(model_id)

model = AutoModelForCausalLM.from_pretrained(
 model_id,
 torch_dtype=torch.float16,
 device_map='auto' # -1 = CPU, 0 = GPU
)

messages = [
 {'role': 'user',
 'content': 'Explain what a transformer is in 3 bullet points for a student.'}
]  #chatML
# prompt + generated op => <|user|> , <|endoftext|>
input_ids = tokenizer.apply_chat_template(messages, return_tensors='pt')['input_ids'].to(model.device)

output = model.generate(
 input_ids,
 max_new_tokens=256,
 temperature=0.7,
 do_sample=True
)
#num_return_sequences = 1
#output = [res1] => output[0] =>numerical
# row 0 : prompt + rwo 1: generated op => <|user|> , <|endoftext|>
response = tokenizer.decode(output[0][input_ids.shape[1]:], skip_special_tokens=True)
print(response)
